# %%
import emcee

# %%
npzfile = np.load('outputs/emcee.npz')

# %%
npzfile['names']
# Out:
# array(['A_lens', 'r_tensor', 'beta_d', 'epsilon_ds', 'alpha_d_bb',
#        'amp_d_bb', 'beta_s', 'alpha_s_bb', 'amp_s_bb'], dtype='<U10')

# %%
npzfile['chain'].shape
# Out:
# (24, 10000, 9)

# %%
import matplotlib.pyplot as plt

# %%
samples = npzfile['chain'].reshape(-1,9)

# %%
i = 1
plt.hist(samples[:,i], bins=50)
plt.xlabel(npzfile['names'][i])
plt.xlim(np.mean(samples[:,i])-4*np.std(samples[:,i]), np.mean(samples[:,i])+4*np.std(samples[:,i]))
# Out:
# (-0.003684239912320872, 0.0038516818687646752)

# %%
import getdist
from getdist import plots, MCSamples

# %%
g = plots.get_subplot_plotter()
g.triangle_plot(
    getdist.MCSamples(
        samples=npzfile['chain'][0],
        names=npzfile['names']),
    filled=True)
# Out:
# Removed no burn in

# %%
a = np.triu_indices(4,-4)

# %%
for i,j in zip(*a):
    print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 0 3
# 1 0
# 1 1
# 1 2
# 1 3
# 2 0
# 2 1
# 2 2
# 2 3
# 3 0
# 3 1
# 3 2
# 3 3

# %%
a[0].shape
# Out:
# (16,)
